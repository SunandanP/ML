# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("temperatures.csv")
df
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0    1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47
# 1    1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80
# 2    1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85
# 3    1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04
# 4    1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112  2013  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04
# 113  2014  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68
# 114  2015  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55
# 115  2016  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66
# 116  2017  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# ...

# %%
x = df.YEAR
x = x.values.reshape(117,1)
x
# Out:
# array([[1901],
#        [1902],
#        [1903],
#        [1904],
#        [1905],
#        [1906],
#        [1907],
#        [1908],
#        [1909],
#        [1910],
#        [1911],
#        [1912],
#        [1913],
#        [1914],
#        [1915],
#        [1916],
#        [1917],
#        [1918],
#        [1919],
#        [1920],
#        [1921],
#        [1922],
#        [1923],
#        [1924],
#        [1925],
#        [1926],
#        [1927],
#        [1928],
#        [1929],
#        [1930],
#        [1931],
#        [1932],
#        [1933],
#        [1934],
#        [1935],
#        [1936],
#        [1937],
#        [1938],
#        [1939],
#        [1940],
#        [1941],
#        [1942],
#        [1943],
#        [1944],
#        [1945],
#        [1946],
#        [1947],
#        [1948],
#        [1949],
#        [1950],
#        [1951],
#        [1952],
#        [1953],
#        [1954],
#        [1955],
#        [1956],
#        [1957],
#        [1958],
# ...

# %%
y = pd.DataFrame({
    "Jan" : df.JAN,
    "Feb" : df.FEB,
    "Mar" : df.MAR,
    "Apr" : df.APR,
    "May" : df.MAR,
    "Jun" : df.JUN,
    "Jul" : df.JUL,
    "Aug" : df.AUG,
    "Sep" : df.SEP,
    "Oct" : df.OCT,
    "Nov" : df.NOV,
    "Dec" : df.DEC
})
# Out:
# array([[22.4 ],
#        [24.93],
#        [23.44],
#        [22.5 ],
#        [22.  ],
#        [22.28],
#        [24.46],
#        [23.57],
#        [22.67],
#        [23.24],
#        [23.22],
#        [23.7 ],
#        [23.71],
#        [24.42],
#        [22.6 ],
#        [24.13],
#        [23.68],
#        [22.06],
#        [23.32],
#        [22.87],
#        [23.57],
#        [22.96],
#        [23.25],
#        [22.84],
#        [22.56],
#        [23.54],
#        [23.23],
#        [23.33],
#        [23.05],
#        [22.6 ],
#        [24.57],
#        [24.13],
#        [22.85],
#        [22.76],
#        [22.28],
#        [23.1 ],
#        [23.34],
#        [22.95],
#        [23.61],
#        [23.79],
#        [23.18],
#        [22.99],
#        [22.97],
#        [23.17],
#        [22.38],
#        [24.41],
#        [22.61],
#        [22.87],
#        [24.31],
#        [23.56],
#        [24.36],
#        [23.91],
#        [22.96],
#        [22.79],
#        [23.46],
# ...

# %%
# reshaping the temperatures
for a in y:
    q = [z for z in y[a]]
    q = pd.Series(q)
    y[a] = q.values.reshape(117,1)

# %%
y.Jan.shape
# Out:
# (117,)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressors = []
for a in y:
    reg = LinearRegression()
    regressors.append(reg)
    reg.fit(x,y[a])

# %%
regressors
# Out:
# [LinearRegression(),
#  LinearRegression(),
#  LinearRegression(),
#  LinearRegression(),
#  LinearRegression(),
#  LinearRegression(),
#  LinearRegression(),
#  LinearRegression(),
#  LinearRegression(),
#  LinearRegression(),
#  LinearRegression(),
#  LinearRegression()]

# %%
def plot(datax, years, label,c):
    plt.subplot(6,2,c)
    plt.title(label)
    plt.xlabel("Year")
    plt.ylabel("Temperature")
    plt.scatter(years,datax)

# %%
plt.figure(figsize=(15,15))
count = 1
for a in y:
    plot(y[a], x, a, count)
    count += 1

# %%
def plotReg(a, b, c):
    plt.subplot(6,2,c)
    sns.regplot(x=a, y=b)

# %%
import seaborn as sns

# %%
count = 1
plt.figure(figsize=(20,20))
for a in y:
    plotReg(x, y[a], count)
    count += 1

# %%
predictions = []
for a in regressors:
    predictions.append(a.predict(x))

# %%
# Report generation
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

mean_Squared = []
count = 0
for a in y:
    mean_Squared.append(mean_squared_error(y[a], predictions[count]))
    count += 1
mean_Squared
# Out:
# [0.4618622899063735,
#  0.7632090585324084,
#  0.7845970575546054,
#  0.5551140421996035,
#  0.7845970575546054,
#  0.3424789478589651,
#  0.1680153135216011,
#  0.1286855314127445,
#  0.16421934291650986,
#  0.3222291272297155,
#  0.2596430611566221,
#  0.2816953369966604]

# %%
mean_abs = []
count = 0
for a in y:
    mean_abs.append(mean_absolute_error(y[a], predictions[count]))
    count += 1
mean_abs
# Out:
# [0.5269972511599087,
#  0.6789777348777175,
#  0.7144189362433303,
#  0.5847609638833843,
#  0.7144189362433303,
#  0.48168799010531976,
#  0.3147989975526732,
#  0.28216620536721243,
#  0.3116818650630036,
#  0.4277138998967587,
#  0.3802875969088565,
#  0.3809487172229012]

# %%
r2 = []
count = 0
for a in y:
    r2.append(r2_score(y[a], predictions[count]))
    count += 1
r2
# Out:
# [0.33119961409323107,
#  0.4186946350416667,
#  0.3067894883332336,
#  0.29231552255304727,
#  0.3067894883332336,
#  0.1382651229137435,
#  0.2289740991326562,
#  0.4278964643910893,
#  0.4409068831359595,
#  0.3470074394986208,
#  0.4870455692427764,
#  0.5361483799594717]
